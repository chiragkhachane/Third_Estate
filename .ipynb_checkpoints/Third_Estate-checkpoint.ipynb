# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/v8/l86t8bw554zbhbyt6gc1v7z40000gn/T/ipykernel_11911/853042502.py in <module>
#       1 import pandas as pd
# ----> 2 from google.colab import drive
#       3
#       4 # Mount Google Drive
#       5 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
# Define the path to your CSV file in Google Drive
csv_file_path = '/Users/chiragkhachane/Library/CloudStorage/OneDrive-UniversityatBuffalo/UB/Experential IT/Datasets to merge/MasterData3.csv'  # Update with your actual file path

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)
'''
selected_features = [
    'SBL', 'PrintKey', 'Address', 'Front', 'Depth', 'TaxDistrict', 'PropertyClassCode',
    'PropClassDescription', 'PreviousPropertyClass', 'Owner1', 'Owner2', 'Mail1', 'Mail2',
    'Mail3', 'Mail4', 'SalePrice', 'YearBuilt', 'TotalValue', 'LandValue', 'NumberofUnits',
    'Acres', 'TotalLivingArea', 'BuildingStyleDescription', 'HeatTypeDescription', 'Neighborhood'
]
'''
# Select only the relevant features from the DataFrame
##df = df[selected_features]

# Display the first few rows of the DataFrame
df.head()
# Out:
# /var/folders/v8/l86t8bw554zbhbyt6gc1v7z40000gn/T/ipykernel_11911/3333243148.py:5: DtypeWarning: Columns (0,11,12,13,18,42,56,57,59,60,62,64,66,82,83,84,85,86,87,88,95,96,100,108,109,110,115,116,117,118,132,140,141,142,149,150,151,152) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#                 SBL        PrintKey                Address  Front  Depth  \
# 0  1120900001001210   112.09-1-1.21            9999 NYC RR    0.0    0.0
# 1  1005200003010110  100.52-3-10.11              13 FRENCH   27.0  135.0
# 2  5550000012004000     555.00-12-4   34 SPECIAL FRANCHISE    0.0    0.0
# 3  5550000091020000    555.00-91-20  104 SPECIAL FRANCHISE    0.0    0.0
# 4  5550000091016000    555.00-91-16  100 SPECIAL FRANCHISE    0.0    0.0
#
#    TaxDistrict  PropertyClassCode           PropClassDescription  \
# 0       147012              842.0               CEILING RAILROAD
# ...

# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport

#df.drop('CaseReference')

profile = ProfileReport(df, title='ThirdEstate_Report')
profile.to_notebook_iframe()
profile.to_file('ThirdEstate_Report.html')
